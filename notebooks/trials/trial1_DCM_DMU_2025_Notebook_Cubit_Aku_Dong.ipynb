# %% [markdown]
# <a href="https://colab.research.google.com/github/LatiefDataVisionary/data-quest-challenge-dsi-2025/blob/main/notebooks/awalan_DCM_DMU_2025_Notebook_Cubit_Aku_Dong.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
val_path = 'https://raw.githubusercontent.com/LatiefDataVisionary/data-quest-challenge-dsi-2025/refs/heads/main/datasets/raw/validation_set.csv'
trai_path = 'https://raw.githubusercontent.com/LatiefDataVisionary/data-quest-challenge-dsi-2025/refs/heads/main/datasets/raw/training_dataset.csv'
df_val = pd.read_csv(val_path)
df_trai = pd.read_csv(trai_path)

# %%
df_val.head()
# Out:
#    customer_number  usia      pekerjaan status_perkawinan pendidikan  \
# 0           445420    35  penyedia jasa           menikah        SMA
# 1           585604    52        teknisi            lajang    Diploma
# 2           888824    37  pekerja kasar           menikah        SMP
# 3           816820    51   pengangguran           menikah    Diploma
# 4           542716    45        teknisi             cerai        SMA
#
#   gagal_bayar_sebelumnya pinjaman_rumah pinjaman_pribadi jenis_kontak  \
# 0                     no            yes              yes     cellular
# 1                unknown             no               no    telephone
# 2                unknown            yes               no    telephone
# 3                     no             no               no    telephone
# 4                     no            yes               no     cellular
#
#   bulan_kontak_terakhir  ... jumlah_kontak_kampanye_ini  \
# 0                   jul  ...                          1
# ...

# %%
df_trai.head()
# Out:
#    customer_number  usia               pekerjaan status_perkawinan  \
# 0           531036    63  sosial media specialis           menikah
# 1           999241    43                 teknisi           menikah
# 2           995002    29  sosial media specialis            lajang
# 3           932750    40           pekerja kasar           menikah
# 4           684699    40  sosial media specialis            lajang
#
#           pendidikan gagal_bayar_sebelumnya pinjaman_rumah pinjaman_pribadi  \
# 0  Pendidikan Tinggi                     no            yes               no
# 1  Pendidikan Tinggi                     no            yes               no
# 2  Pendidikan Tinggi                     no            yes              yes
# 3                SMA                     no             no               no
# 4  Pendidikan Tinggi                     no             no               no
#
#   jenis_kontak bulan_kontak_terakhir  ... hari_sejak_kontak_sebelumnya  \
# ...

# %%
df_val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5729 entries, 0 to 5728
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   customer_number               5729 non-null   int64
#  1   usia                          5729 non-null   int64
#  2   pekerjaan                     5729 non-null   object
#  3   status_perkawinan             5729 non-null   object
#  4   pendidikan                    5729 non-null   object
#  5   gagal_bayar_sebelumnya        5729 non-null   object
#  6   pinjaman_rumah                5729 non-null   object
#  7   pinjaman_pribadi              5729 non-null   object
#  8   jenis_kontak                  5729 non-null   object
#  9   bulan_kontak_terakhir         5729 non-null   object
#  10  hari_kontak_terakhir          5729 non-null   object
#  11  jumlah_kontak_kampanye_ini    5729 non-null   int64
# ...

# %%
df_trai.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22916 entries, 0 to 22915
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   customer_number               22916 non-null  int64
#  1   usia                          22916 non-null  int64
#  2   pekerjaan                     22916 non-null  object
#  3   status_perkawinan             22916 non-null  object
#  4   pendidikan                    22916 non-null  object
#  5   gagal_bayar_sebelumnya        22916 non-null  object
#  6   pinjaman_rumah                22916 non-null  object
#  7   pinjaman_pribadi              22916 non-null  object
#  8   jenis_kontak                  22916 non-null  object
#  9   bulan_kontak_terakhir         22916 non-null  object
#  10  hari_kontak_terakhir          22916 non-null  object
#  11  jumlah_kontak_kampanye_ini    22916 non-null  int64
# ...

# %%
df_val.describe()
# Out:
#        customer_number         usia  jumlah_kontak_kampanye_ini  \
# count      5729.000000  5729.000000                 5729.000000
# mean     548493.630826    39.852679                    2.545470
# std      258992.541542    10.348971                    2.618704
# min      100423.000000    18.000000                    1.000000
# 25%      323527.000000    32.000000                    1.000000
# 50%      552893.000000    38.000000                    2.000000
# 75%      772131.000000    46.000000                    3.000000
# max      999897.000000    98.000000                   43.000000
#
#        hari_sejak_kontak_sebelumnya  jumlah_kontak_sebelumnya  \
# count                   5729.000000               5729.000000
# mean                     964.329377                  0.162157
# std                      182.310129                  0.471306
# min                        0.000000                  0.000000
# 25%                      999.000000                  0.000000
# ...

# %%
df_trai.describe()
# Out:
#        customer_number          usia  jumlah_kontak_kampanye_ini  \
# count     22916.000000  22916.000000                22916.000000
# mean     550930.993193     40.016233                    2.561878
# std      259909.889175     10.438059                    2.794178
# min      100108.000000     17.000000                    1.000000
# 25%      325755.000000     32.000000                    1.000000
# 50%      553139.000000     38.000000                    2.000000
# 75%      777157.500000     47.000000                    3.000000
# max      999997.000000     98.000000                   42.000000
#
#        hari_sejak_kontak_sebelumnya  jumlah_kontak_sebelumnya  \
# count                  22916.000000              22916.000000
# mean                     962.210377                  0.170143
# std                      187.566774                  0.490611
# min                        0.000000                  0.000000
# 25%                      999.000000                  0.000000
# ...

# %%
for col in df_trai.columns:
  if df_trai[col].dtype == 'object' or df_trai[col].dtype.name == 'category':
    print(f"Kolom '{col}': {df_trai[col].unique().tolist()}")
# Out:
# Kolom 'pekerjaan': ['sosial media specialis', 'teknisi', 'pekerja kasar', 'manajer', 'asisten rumah tangga', 'mahasiswa', 'penyedia jasa', 'pemilik bisnis', 'entrepreneur', 'pengangguran', 'pensiunan', 'unknown']
# Kolom 'status_perkawinan': ['menikah', 'lajang', 'cerai', 'unknown']
# Kolom 'pendidikan': ['Pendidikan Tinggi', 'SMA', 'Tidak Tamat SD', 'SMP', 'Diploma', 'SD', 'unknown', 'TIDAK SEKOLAH']
# Kolom 'gagal_bayar_sebelumnya': ['no', 'unknown', 'yes']
# Kolom 'pinjaman_rumah': ['yes', 'no', 'unknown']
# Kolom 'pinjaman_pribadi': ['no', 'yes', 'unknown']
# Kolom 'jenis_kontak': ['cellular', 'telephone']
# Kolom 'bulan_kontak_terakhir': ['jul', 'nov', 'may', 'aug', 'oct', 'apr', 'jun', 'sep', 'mar', 'dec']
# Kolom 'hari_kontak_terakhir': ['fri', 'thu', 'wed', 'tue', 'mon']
# Kolom 'hasil_kampanye_sebelumnya': ['nonexistent', 'failure', 'success']
# Kolom 'pulau': ['Papua', 'Sulawesi', 'Sumatera', 'Bali', 'NTT', 'Jawa', 'NTB', 'Kalimantan']

# %%
for col in df_val.columns:
  if df_val[col].dtype == 'object' or df_val[col].dtype.name == 'category':
    print(f"Kolom '{col}': {df_val[col].unique().tolist()}")
# Out:
# Kolom 'pekerjaan': ['penyedia jasa', 'teknisi', 'pekerja kasar', 'pengangguran', 'sosial media specialis', 'pensiunan', 'asisten rumah tangga', 'manajer', 'mahasiswa', 'entrepreneur', 'pemilik bisnis', 'unknown']
# Kolom 'status_perkawinan': ['menikah', 'lajang', 'cerai', 'unknown']
# Kolom 'pendidikan': ['SMA', 'Diploma', 'SMP', 'Tidak Tamat SD', 'SD', 'Pendidikan Tinggi', 'unknown', 'TIDAK SEKOLAH']
# Kolom 'gagal_bayar_sebelumnya': ['no', 'unknown']
# Kolom 'pinjaman_rumah': ['yes', 'no', 'unknown']
# Kolom 'pinjaman_pribadi': ['yes', 'no', 'unknown']
# Kolom 'jenis_kontak': ['cellular', 'telephone']
# Kolom 'bulan_kontak_terakhir': ['jul', 'may', 'jun', 'apr', 'nov', 'aug', 'mar', 'dec', 'sep', 'oct']
# Kolom 'hari_kontak_terakhir': ['mon', 'thu', 'wed', 'tue', 'fri']
# Kolom 'hasil_kampanye_sebelumnya': ['nonexistent', 'failure', 'success']
# Kolom 'pulau': ['Jawa', 'Papua', 'Bali', 'Sumatera', 'Kalimantan', 'NTB', 'NTT', 'Sulawesi']
